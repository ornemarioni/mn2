# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Acá ponemos el ejemplo del seed() para setear la semilla inicial del random
# y obtener siempre el mismo número.
import random 
random.seed(7)
a = random.random()
print a
# Out:
# 0.323832764833

# %% [markdown]
# # Distribución homogenea dentro de un box de lado 1

# %%
import random

N = 4096 #numero de particulas en el box
random.seed(27)

sample = np.arange(0,1,1e-5)
x = random.sample(sample, N)
y = random.sample(sample, N)
z = random.sample(sample, N)

# %%
import matplotlib.pyplot as plt
from __future__ import unicode_literals

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True

fig = plt.figure(1, figsize=(16,8))
fig.subplots_adjust(bottom=0.15, left =0.16, right = 0.95, top = 0.95)

ax1 = fig.add_subplot(121)
ax1.plot(x,y,'.k', markersize=3)
ax1.minorticks_on()
ax1.tick_params( labelsize=24)
ax1.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax1.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax1.set_xlabel('$\mathrm{x}$', fontsize=24)
ax1.set_ylabel('$\mathrm{y}$', fontsize=24)

ax2 = fig.add_subplot(122)
ax2.plot(x,z,'.k', markersize=3)
ax2.minorticks_on()
ax2.tick_params( labelsize=24)
ax2.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax2.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax2.set_xlabel('$\mathrm{x}$', fontsize=24)
ax2.set_ylabel('$\mathrm{z}$', fontsize=24)

plt.show()

# %% [markdown]
# ### Histogramas

# %%
import matplotlib.pyplot as plt
from __future__ import unicode_literals

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True

fig = plt.figure(1, figsize=(21,6))
fig.subplots_adjust(bottom=0.15, left =0.16, right = 0.95, top = 0.95)

ax1 = fig.add_subplot(131)
ax1.hist(x, edgecolor = 'black')
ax1.minorticks_on()
ax1.tick_params( labelsize=24)
ax1.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax1.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax1.set_xlabel('$\mathrm{x}$', fontsize=24)

ax2 = fig.add_subplot(132)
ax2.hist(y, edgecolor = 'black')
ax2.minorticks_on()
ax2.tick_params( labelsize=24)
ax2.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax2.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax2.set_xlabel('$\mathrm{y}$', fontsize=24)

ax3 = fig.add_subplot(133)
ax3.hist(z, edgecolor = 'black')
ax3.minorticks_on()
ax3.tick_params( labelsize=24)
ax3.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax3.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax3.set_xlabel('$\mathrm{z}$', fontsize=24)

plt.show()

# %% [markdown]
# # Distribucion homogenea en una esfera de radio 1

# %%
import random
import numpy as np

N = 10000
random.seed(27)
sample = np.arange(0,1,1e-5)
    
r3 = random.sample(sample, N)
r3 = np.asarray(r3)

cos_t = random.sample(sample, N)
cos_t = np.asarray(cos_t) * 2. - 1

phi = random.sample(sample, N)
phi = np.asarray(phi) * 2. * np.pi 

sin_t = np.sqrt(1 - cos_t**2)

x = r3**(1/3.) * sin_t * np.cos(phi)
y = r3**(1/3.) * sin_t * np.sin(phi)
z = r3**(1/3.) * cos_t

# %%
import matplotlib.pyplot as plt
from __future__ import unicode_literals

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True

fig = plt.figure(1, figsize=(16,7))
fig.subplots_adjust(bottom=0.15, left =0.16, right = 0.95, top = 0.95)

ax1 = fig.add_subplot(121)
ax1.plot(x,y,'.k', markersize=3)
ax1.minorticks_on()
ax1.tick_params( labelsize=24)
ax1.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax1.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax1.set_xlabel('$\mathrm{x}$', fontsize=24)
ax1.set_ylabel('$\mathrm{y}$', fontsize=24)

ax2 = fig.add_subplot(122)
ax2.plot(x,z,'.k', markersize=3)
ax2.minorticks_on()
ax2.tick_params( labelsize=24)
ax2.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax2.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax2.set_xlabel('$\mathrm{x}$', fontsize=24)
ax2.set_ylabel('$\mathrm{z}$', fontsize=24)

plt.show()

# %% [markdown]
# ### Histogramas

# %%
import matplotlib.pyplot as plt
from __future__ import unicode_literals

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True

fig = plt.figure(1, figsize=(21,6))
fig.subplots_adjust(bottom=0.15, left =0.16, right = 0.95, top = 0.95)

ax1 = fig.add_subplot(131)
ax1.hist(r3, edgecolor = 'black')
ax1.minorticks_on()
ax1.tick_params( labelsize=24)
ax1.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax1.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax1.set_xlabel('$\mathrm{r^{3}}$', fontsize=24)

ax2 = fig.add_subplot(132)
ax2.hist(cos_t, edgecolor = 'black')
ax2.minorticks_on()
ax2.tick_params( labelsize=24)
ax2.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax2.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax2.set_xlabel(r'$\mathrm{cos(\theta)}$', fontsize=24)

ax3 = fig.add_subplot(133)
ax3.hist(phi, edgecolor = 'black')
ax3.minorticks_on()
ax3.tick_params( labelsize=24)
ax3.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax3.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax3.set_xlabel('$\mathrm{\phi}$', fontsize=24)

plt.show()

# %% [markdown]
# ## Densidad con bines equiespaciados en r

# %%
r = r3**(1/3.)

rbin = np.linspace(1./60., 1, 30)

vol = 4/3. * np.pi * ((rbin+1./60)**3. - (rbin-1./60)**3.)

aux = np.int_(r*len(rbin))
Npart = np.ones(N)
count = np.zeros(len(rbin))

for i in range(0,N):
    count[aux[i]] = count[aux[i]] + Npart[i] 

rho = count / vol

# %%
import matplotlib.pyplot as plt
import numpy as np
from __future__ import unicode_literals

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True

fig = plt.figure(1, figsize=(8,8))
fig.subplots_adjust(bottom=0.15, left =0.16, right = 0.95, top = 0.95)

ax1 = fig.add_subplot(111)
ax1.plot(rbin, rho, '.k', markersize=5)
ax1.minorticks_on()
ax1.tick_params( labelsize=24)
ax1.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax1.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax1.set_xlabel('$\mathrm{r}$', fontsize=24)
ax1.set_ylabel(r'$\mathrm{\rho}$', fontsize=24)
ax1.set_ylim(1000,13000)
plt.show()

# %% [markdown]
# ## Densidad con bines equal number

# %%
import bines

r = r3**(1/3.)
rbin,nodos = bines.rbin1(r,Nbin)
count = np.zeros(len(rbin))
vol = np.zeros(len(rbin))

for i in range(0,len(nodos)-1):
    vol[i] = 4/3. * np.pi * (nodos[i+1]**3. - nodos[i]**3.)
    mask, = np.where((r>nodos[i]) & (r<nodos[i+1]))
    count[i] = len(r[mask])

rho = count / vol

# %%
import matplotlib.pyplot as plt
import numpy as np
from __future__ import unicode_literals

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True

fig = plt.figure(1, figsize=(8,8))
fig.subplots_adjust(bottom=0.15, left =0.16, right = 0.95, top = 0.95)

ax1 = fig.add_subplot(111)
ax1.plot(rbin, rho, '.k', markersize=5)
ax1.minorticks_on()
ax1.tick_params( labelsize=24)
ax1.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax1.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax1.set_xlabel('$\mathrm{r}$', fontsize=24)
ax1.set_ylabel(r'$\mathrm{\rho}$', fontsize=24)
ax1.set_ylim(1000,13000)

plt.show()

# %% [markdown]
# # Distribucion en una esfera de radio 1 que decae como $1/r^2$

# %%
import random
import numpy as np

N = 10000
sample = np.arange(0,1,1e-5)
    
r = random.sample(sample, N)
r = np.asarray(r)

cos_t = random.sample(sample, N)
cos_t = np.asarray(cos_t) * 2. - 1

phi = random.sample(sample, N)
phi = np.asarray(phi) * 2. * np.pi 

sin_t = np.sqrt(1 - cos_t**2)

x = r * sin_t * np.cos(phi)
y = r * sin_t * np.sin(phi)
z = r * cos_t

# %%
import matplotlib.pyplot as plt
from __future__ import unicode_literals

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True

fig = plt.figure(1, figsize=(16,7))
fig.subplots_adjust(bottom=0.15, left =0.16, right = 0.95, top = 0.95)

ax1 = fig.add_subplot(121)
ax1.plot(x,y,'.k', markersize=3)
ax1.minorticks_on()
ax1.tick_params( labelsize=24)
ax1.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax1.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax1.set_xlabel('$\mathrm{x}$', fontsize=24)
ax1.set_ylabel('$\mathrm{y}$', fontsize=24)

ax2 = fig.add_subplot(122)
ax2.plot(x,z,'.k', markersize=3)
ax2.minorticks_on()
ax2.tick_params( labelsize=24)
ax2.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax2.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax2.set_xlabel('$\mathrm{x}$', fontsize=24)
ax2.set_ylabel('$\mathrm{z}$', fontsize=24)

plt.show()

# %% [markdown]
# ### Histogramas

# %%
import matplotlib.pyplot as plt
from __future__ import unicode_literals

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True

fig = plt.figure(1, figsize=(21,6))
fig.subplots_adjust(bottom=0.15, left =0.16, right = 0.95, top = 0.95)

ax1 = fig.add_subplot(131)
ax1.hist(r, edgecolor = 'black')
ax1.minorticks_on()
ax1.tick_params( labelsize=24)
ax1.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax1.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax1.set_xlabel('$\mathrm{r}$', fontsize=24)

ax2 = fig.add_subplot(132)
ax2.hist(cos_t, edgecolor = 'black')
ax2.minorticks_on()
ax2.tick_params( labelsize=24)
ax2.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax2.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax2.set_xlabel(r'$\mathrm{cos(\theta)}$', fontsize=24)

ax3 = fig.add_subplot(133)
ax3.hist(phi, edgecolor = 'black')
ax3.minorticks_on()
ax3.tick_params( labelsize=24)
ax3.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax3.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax3.set_xlabel('$\mathrm{\phi}$', fontsize=24)

plt.show()

# %% [markdown]
# ## Densidad con bines equiespaciados en r

# %%
rbin = np.arange(1./60, 1, 1./30)

vol = 4/3. * np.pi * ((rbin+1./60)**3. - (rbin-1./60)**3.)

aux = np.int_(r*len(rbin))
Npart = np.ones(N)
count = np.zeros(len(rbin))

for i in range(0,N):
    count[aux[i]] = count[aux[i]] + Npart[i] 

rho = count / vol

# print count
# print range(1,len(r)+1)
# print r_sort[0]
# print rho#, vol

# %%
m,b = polyfit(np.log10(rbin), np.log10(rho),1)
print m,b
# Out:
# -1.9692547910235143 2.9080268816965433

# %%
import matplotlib.pyplot as plt
import numpy as np
from __future__ import unicode_literals

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True

fig = plt.figure(1, figsize=(8,8))
fig.subplots_adjust(bottom=0.15, left =0.16, right = 0.95, top = 0.95)

ax1 = fig.add_subplot(111)
ax1.plot(np.log10(rbin), np.log10(rho), '.k', markersize=10)
ax1.plot(np.log10(rbin), m*np.log10(rbin)+b, '-r', lw=2)
ax1.minorticks_on()
ax1.tick_params( labelsize=24)
ax1.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax1.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax1.set_xlabel('$\mathrm{log(r)}$', fontsize=24)
ax1.set_ylabel(r'$\mathrm{log(\rho)}$', fontsize=24)
# ax1.set_yscale('log')
# ax1.set_xscale('log')
ax1.text(-0.75, 6.25, 'y = mx+b', fontsize=18)
ax1.text(-0.75, 6.0, 'm= -1.9692', fontsize=18)
ax1.text(-0.75, 5.75, 'b= 2.9080', fontsize=18)


plt.show()

# %% [markdown]
# ## Densidad con bines equiespaciados en log(r)

# %%
rbin = np.linspace(np.log10(1./60), 0, 30)

vol = 4/3. * np.pi * ((10**rbin+1/60.)**3-(10**rbin-1/60.)**3)

aux = np.int_(r*len(rbin))
Npart = np.ones(N)
count = np.zeros(len(rbin))

for i in range(0,N):
    count[aux[i]] = count[aux[i]] + Npart[i] 

rho = count / vol

# %%
m,b = polyfit(rbin, np.log10(rho),1)
print m,b
# Out:
# -1.9564937578724826 2.920742123337635

# %%
import matplotlib.pyplot as plt
import numpy as np
from __future__ import unicode_literals

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True

fig = plt.figure(1, figsize=(8,8))
fig.subplots_adjust(bottom=0.15, left =0.16, right = 0.95, top = 0.95)

ax1 = fig.add_subplot(111)
ax1.plot(rbin, np.log10(rho), '.k', markersize=10)
ax1.plot(rbin, m*rbin+b, '-r', lw=2)

ax1.minorticks_on()
ax1.tick_params( labelsize=24)
ax1.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax1.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax1.set_xlabel('$\mathrm{log(r)}$', fontsize=24)
ax1.set_ylabel(r'$\mathrm{log(\rho)}$', fontsize=24)
# ax1.set_yscale('log')
# ax1.set_xscale('log')
ax1.text(-0.75, 6.25, 'y = mx+b', fontsize=18)
ax1.text(-0.75, 6.0, 'm= -1.9564', fontsize=18)
ax1.text(-0.75, 5.75, 'b= 2.9207', fontsize=18)


plt.show()

# %% [markdown]
# ## Densidad con bines equal number

# %%
import bines

rbin,nodos = bines.rbin1(r,30)
count = np.zeros(len(rbin))
vol = np.zeros(len(rbin))
for i in range(0,len(nodos)-1):
    vol[i] = 4/3. * np.pi * (nodos[i+1]**3. - nodos[i]**3.)
    mask, = np.where((r>nodos[i]) & (r<nodos[i+1]))
    count[i] = len(r[mask])

rho = count / vol

# %%
m,b = polyfit(np.log10(rbin), np.log10(rho),1)
print m,b
# Out:
# -1.9800233879126174 2.905170966671597

# %%
import matplotlib.pyplot as plt
import numpy as np
from __future__ import unicode_literals

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True

fig = plt.figure(1, figsize=(8,8))
fig.subplots_adjust(bottom=0.15, left =0.16, right = 0.95, top = 0.95)

ax1 = fig.add_subplot(111)
ax1.plot(np.log10(rbin),np.log10(rho), '.k', markersize=10)
ax1.plot(np.log10(rbin), m*np.log10(rbin)+b, '-r', lw=2)
ax1.minorticks_on()
ax1.tick_params( labelsize=24)
ax1.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax1.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax1.set_xlabel('$\mathrm{log(r)}$', fontsize=24)
ax1.set_ylabel(r'$\mathrm{log(\rho)}$', fontsize=24)
# ax1.set_yscale('log')
# ax1.set_xscale('log')
ax1.text(-0.75, 6.25, 'y = mx+b', fontsize=18)
ax1.text(-0.75, 6.0, 'm= -1.9800', fontsize=18)
ax1.text(-0.75, 5.75, 'b= 2.9051', fontsize=18)


plt.show()

# %% [markdown]
# ## Kernel con soporte compacto (Ec. 4.21)

# %%
import numpy as np

#Spline kernel of Monaghan and Lattanzio (1985)
def W(r,h):
    
    n=len(r)
    
    x = r/h
    W = np.zeros(n)
    
    for i in range(n):
        
        if 0.<= x[i] and x[i] < 1. :
            W[i] = (1. - 1.5*(x[i]**2) + 0.75*(x[i]**3)) / (np.pi * h**3)
        
        elif 1.<= x[i] and x[i] < 2. :
            W[i] = (2. - x[i])**3 / (4 * np.pi * h**3)
        
        else:
            W[i] = 0.
    
    return W

# %%
h = 0.5
r = frange(0,2.,0.001)

import matplotlib.pyplot as plt
import numpy as np
from __future__ import unicode_literals
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True

fig = plt.figure(1, figsize=(8,8))
fig.subplots_adjust(bottom=0.15, left =0.16, right = 0.95, top = 0.95)

ax1 = fig.add_subplot(111)
ax1.plot(r, W(r,h), '.k', markersize=5)
ax1.minorticks_on()
ax1.tick_params( labelsize=24)
ax1.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax1.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax1.set_xlabel('$\mathrm{r}$', fontsize=24)
ax1.set_ylabel(r'$\mathrm{W(r,h)}$', fontsize=24)


plt.show()

# %% [markdown]
# #### Gradiente del kernel W(r,h)

# %%
def dW(r,h):

    n=len(r)
    x = r/h
    dW = np.zeros(n)
    
    for i in range(n):
        
        if 0.<= x[i] and x[i] < 1. :
            dW[i] = 3 * ((0.75 * x[i]**2) - x[i]) / (np.pi * h**4)
        
        elif 1.<= x[i] and x[i] < 2. :
            dW[i] = -3. * (2. - x[i])**2 / (4 * np.pi * h**4)
        
        else:
            dW[i] = 0.
    
    return dW

# %%
h = 0.5
r = frange(0,2.,0.001)

import matplotlib.pyplot as plt
import numpy as np
from __future__ import unicode_literals
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True

fig = plt.figure(1, figsize=(8,8))
fig.subplots_adjust(bottom=0.15, left =0.16, right = 0.95, top = 0.95)

ax1 = fig.add_subplot(111)
ax1.plot(r, dW(r,h), '.k', markersize=5)
ax1.minorticks_on()
ax1.tick_params( labelsize=24)
ax1.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax1.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax1.set_xlabel('$\mathrm{r}$', fontsize=24)
ax1.set_ylabel(r'$\mathrm{\nabla W(r,h)}$', fontsize=24)


plt.show()

# %% [markdown]
# ## Linked list

# %%
import random

N = 4096 #numero de particulas en el box
random.seed(27)

sample = np.arange(0,1,1e-5)

x = random.sample(sample, N)
y = random.sample(sample, N)
z = random.sample(sample, N)

x = np.asarray(x)
y = np.asarray(y)
z = np.asarray(z)

# %%
import matplotlib.pyplot as plt
from __future__ import unicode_literals

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True

fig = plt.figure(1, figsize=(16,8))
fig.subplots_adjust(bottom=0.15, left =0.16, right = 0.95, top = 0.95)

ax1 = fig.add_subplot(121)
ax1.plot(x,y,'.k', markersize=3)
ax1.minorticks_on()
ax1.tick_params( labelsize=24)
ax1.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax1.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax1.set_xlabel('$\mathrm{x}$', fontsize=24)
ax1.set_ylabel('$\mathrm{y}$', fontsize=24)

ax2 = fig.add_subplot(122)
ax2.plot(x,z,'.k', markersize=3)
ax2.minorticks_on()
ax2.tick_params( labelsize=24)
ax2.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')
ax2.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on') 
ax2.set_xlabel('$\mathrm{x}$', fontsize=24)
ax2.set_ylabel('$\mathrm{z}$', fontsize=24)

plt.show()

# %%
boxsize = 1.
nx = 10
ny = 10
nz = 10

dx = boxsize/nx #100 es el numero de divisiones
dy = boxsize/ny
dz = boxsize/nz

gridx = np.arange(0, boxsize + dx, dx)
gridy = np.arange(0, boxsize + dy, dy)
gridz = np.arange(0, boxsize + dz, dz)

# %%
xgrid = np.int_(x*nx)
ygrid = np.int_(y*ny)
zgrid = np.int_(z*nz)

h = (xgrid*ny + ygrid)*nz + zgrid #esto nos dice a que numero de grid total corresponde cada conjunto xgrid, ygrid, zgrid.

h = np.int_(h)
print h
print h.min(), h.max()
# Out:
# [670 734 942 ... 289 630 603]
# 0 999

# %% [markdown]
# #### Esto nos da un vector con los IDs de las part ordenadas por celda

# %%
ID_part = np.arange(0,N)

sort = np.argsort(h)

linked_list = ID_part[sort]

print linked_list
# print h[42]
# Out:
# [3980 2902  872 ...   42 3190 3314]

# %% [markdown]
# #### Cantidad de particulas que me caen en cada celda del grid

# %%
count = np.zeros(nx*ny*nz)

for i in range(0,len(h)):
    count[h[i]] += 1

# %%
print count
# Out:
# [ 7.  6.  5.  1.  4.  5.  1.  8.  5.  4.  4.  6.  7.  2.  6.  3.  7.  3.
#   3.  5.  3.  1.  2.  6.  1.  5.  5.  3.  4.  4.  8.  5.  4.  3.  2.  3.
#   2.  3.  5.  5.  4.  5.  3.  2.  2.  2.  2.  4.  2.  6.  3.  4.  4.  5.
#   5.  4.  2.  6.  6.  5.  4.  3.  6.  5.  3.  2.  6.  6.  5.  3.  4.  2.
#   3.  5.  3.  3.  3.  4.  5.  5.  7.  6.  4.  8.  3.  3.  7.  4.  3.  3.
#   1.  4.  1.  2.  8.  1.  1.  4.  1.  2.  6.  4.  4.  3.  3.  1.  1.  4.
#   2.  8.  3.  2.  7.  3.  4.  4.  1.  5.  2.  3.  8.  4.  3.  7.  2.  1.
#   1.  5.  3.  8.  3.  3.  1.  2.  5.  3.  6.  5.  6.  2.  5.  6.  5.  4.
#   6.  6.  4.  6.  3.  9.  2.  1.  4. 10.  6.  7.  4.  4.  5.  3.  2.  5.
#   3.  8.  4.  6.  5.  2.  4.  1.  1.  6.  4.  2.  0.  2.  2.  2.  9.  1.
#   5.  4.  4.  7.  5.  3.  5.  3.  2.  3.  4.  3.  2.  3.  3.  2.  4.  7.
#   5.  6.  2.  2.  3.  1.  3.  7.  7.  3.  4.  2.  4.  1.  4.  8.  2.  2.
#   2.  1.  1.  4.  3.  9.  2.  0.  2.  4.  5.  4.  1.  2.  3.  2.  5.  3.
# ...
